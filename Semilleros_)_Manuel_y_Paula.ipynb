# %%
Profe eso es redificil colocar esa cosa de iamgenes y se me crasheaba a cada rato el navegador quiza porque estoy usando una VPN, y no al puedo quitar que pena ahi le mando un correo con las imagenes :)

# %% [markdown]
# Sistema de sincronia entre equipos de monitoreo de variables fisiologicas:
# **Resumen:** Lo que se busca es encontrar una manera de como variables fisiologics como la temperatura, frecuencia cardiaca y saturacion se pueden llegar a sincornixar en busqueda de mejorar esos procesos de medicion
# ![1577a58a-3b9f-40df-b1a1-d7fb3253f839.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Evaluacion del ruido ambiental en el campus de la Universidad de Santander con un modulo electronico de bajo costo en tiempo real
# **Resumen:** Encontrar los decibeles generados en alguans partes de la universidad con el fin de saber si la contaminacion es muy alta, dando como resultado que la contaminacion no es tan eelvada.

# %% [markdown]
# Solucion al problema de ruteo de vehiculos de fltoa heterogenea con trasbordo lateral mediante la metaheuristica de algoritmo genetico
# **Resumen** Se quiere solucionar un problema que es la principal raiz del traifco y con una idea innovadora y traida de otro ambito como los es el genetico.

# %% [markdown]
# Industria 4,0 y economia circular en el sector servicios **Resumen** La industria 4,0 trae consigno una infinidad de herramientas como el internet de las cosas, y esta Industria tiene que ser llevada a muchos sectores en los cuales hay de la misma manera infinidades de problemas y que aunque las soluciones esten no ha quien guie este proceso.

# %% [markdown]
# :Aplicacion de tecnicas de diagnostico a un plasma generado a partir de fuego excitado por microhondas **Resumen** A traves de un fenoemno fisico raro pero que explica varios ambitos como la excitacion de aprticulas y  el vacio; se intenta conocer mas de este fenomeno y sus posibles formas de apreciarse desde diferentes propositos
